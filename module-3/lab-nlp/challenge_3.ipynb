# %% [markdown]
# # Sentiment Analysis

# %%
import pandas as pd
import re
import nltk
from nltk import word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from stop_words import get_stop_words

# %%
df=pd.read_csv('Sentiment140.csv')

# %%
df.shape
# Out:
# (1600000, 6)

# %%
df.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# ### Funciones

# %%
def clean_up(s):
    
    new_word=re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+',"",s) #Quitas URLs
    new_word=re.sub('[^A-Za-z0-9]+'," ",new_word) #Quitas carácteres especiales
    new_word=re.sub('\d+',"",new_word) #Quitas números
    new_word=new_word.strip()
    
    return new_word

def tokenize(s):
    return word_tokenize(s) 

def stem_and_lemmatize(s):
    stemmer = SnowballStemmer('english')
    lemmatizer = WordNetLemmatizer()
    
    stemmed = [stemmer.stem(i) for i in s]
    s_l = [lemmatizer.lemmatize(i) for i in stemmed]
    
    return s_l

def remove_stopwords(s):
    stop_words = get_stop_words('english')
    clean_s=[]
    for e in s:
        if e not in stop_words:
            clean_s.append(e)
    
    return clean_s

# %%
df['text_processed']=df.text.apply(lambda x: clean_up(x))

df.text_processed=df.text_processed.apply(lambda x: tokenize(x))

df.text_processed=df.text_processed.apply(lambda x: stem_and_lemmatize(x))

df.text_processed=df.text_processed.apply(lambda x: remove_stopwords(x))

# %%
df.text_processed.head()
# Out:
# 0    [switchfoot, awww, s, bummer, shoulda, got, da...
# 1    [upset, can, t, updat, facebook, text, might, ...
# 2    [kenichan, dive, mani, time, ball, manag, save...
# 3               [whole, bodi, feel, itchi, like, fire]
# 4    [nationwideclass, s, behav, m, mad, whi, becau...
# Name: text_processed, dtype: object

# %% [markdown]
# ### Words Freqssss

# %%
from nltk.probability import FreqDist

### EJEMPLO
sent = 'This is an example sentence'
fdist = FreqDist()

for word in word_tokenize(sent):
    fdist[word.lower()] += 1
    
fdist
# Out:
# FreqDist({'this': 1, 'is': 1, 'an': 1, 'example': 1, 'sentence': 1})

# %%
##### Pasando los valores de toda la columna a una sola lista #######

#str(df.text_processed[0])
#df.text_processed[0]

lst=[]
for e in range(len(df)):
        lst += df.text_processed[e]

# %%
lst
# Out:
# ['switchfoot',
#  'awww',
#  's',
#  'bummer',
#  'shoulda',
#  'got',
#  'david',
#  'carr',
#  'third',
#  'day',
#  'd',
#  'upset',
#  'can',
#  't',
#  'updat',
#  'facebook',
#  'text',
#  'might',
#  'cri',
#  'result',
#  'school',
#  'today',
#  'also',
#  'blah',
#  'kenichan',
#  'dive',
#  'mani',
#  'time',
#  'ball',
#  'manag',
#  'save',
#  'rest',
#  'go',
#  'bound',
#  'whole',
#  'bodi',
#  'feel',
#  'itchi',
#  'like',
#  'fire',
#  'nationwideclass',
#  's',
#  'behav',
#  'm',
#  'mad',
#  'whi',
#  'becaus',
#  'can',
#  't',
#  'see',
#  'kwesidei',
#  'whole',
#  'crew',
#  'need',
#  'hug',
#  'loltrish',
#  'hey',
#  'long',
#  'time',
#  'see',
#  'yes',
#  'rain',
#  'bit',
#  'onli',
#  'bit',
#  'lol',
#  'm',
#  'fine',
#  'thank',
#  's',
#  'tatiana',
#  'k',
#  'nope',
#  'didn',
#  't',
#  'twittera',
#  'que',
#  'muera',
#  'spring',
#  'break',
#  'plain',
#  'citi',
#  's',
#  'snow',
#  'just',
#  're',
#  'pierc',
#  'ear',
#  'caregiv',
#  'couldn',
#  't',
#  'bear',
#  'watch',
#  'thought',
#  'ua',
#  'loss',
#  'wa',
#  'embarrass',
#  'octolinz',
#  'count',
#  'idk',
#  'whi',
#  'either',
#  'never',
#  'talk',
#  'anymor',
#  'smarrison',
#  've',
#  'first',
#  'didn',
#  't',
#  'gun',
#  'realli',
#  'though',
#  'zac',
#  'snyder',
#  's',
#  'just',
#  'doucheclown',
#  'iamjazzyfizzl',
#  'wish',
#  'got',
#  'watch',
#  'miss',
#  'iamlilnicki',
#  'wa',
#  'premier',
#  'holli',
#  'death',
#  'scene',
#  'will',
#  'hurt',
#  'sever',
#  'watch',
#  'film',
#  'wri',
#  'director',
#  'cut',
#  'now',
#  'file',
#  'tax',
#  'lettya',
#  'ahh',
#  'ive',
#  'alway',
#  'want',
#  'see',
#  'rent',
#  'love',
#  'soundtrack',
#  'fakerpattypattz',
#  'oh',
#  'dear',
#  'drink',
#  'forgotten',
#  'tabl',
#  'drink',
#  'alydesign',
#  'wa',
#  'day',
#  'didn',
#  't',
#  'get',
#  'much',
#  'done',
#  'one',
#  'friend',
#  'call',
#  'ask',
#  'meet',
#  'mid',
#  'valley',
#  'today',
#  've',
#  'time',
#  'sigh',
#  'angri',
#  'barista',
#  'bake',
#  'cake',
#  'ate',
#  'week',
#  'go',
#  'hope',
#  'blagh',
#  'class',
#  'tomorrow',
#  'hate',
#  'call',
#  'wake',
#  'peopl',
#  'just',
#  'go',
#  'cri',
#  'sleep',
#  'watch',
#  'marley',
#  'im',
#  'sad',
#  'now',
#  'miss',
#  'lilli',
#  'ooooh',
#  'lol',
#  'lesli',
#  'ok',
#  'won',
#  't',
#  'lesli',
#  'won',
#  't',
#  'get',
#  'mad',
#  'meh',
#  'almost',
#  'lover',
#  'except',
#  'track',
#  'get',
#  'depress',
#  'everi',
#  'time',
#  'hack',
#  'account',
#  'aim',
#  'now',
#  'make',
#  'new',
#  'one',
#  'alielayus',
#  'want',
#  'go',
#  'promot',
#  'gear',
#  'groov',
#  'unforn',
#  'ride',
#  'may',
#  'b',
#  'go',
#  'one',
#  'anaheim',
#  'may',
#  'though',
#  'thought',
#  'sleep',
#  'wa',
#  'option',
#  'tomorrow',
#  'realiz',
#  'now',
#  'evalu',
#  'morn',
#  'work',
#  'afternoon',
#  'julieebabi',
#  'awe',
#  'love',
#  'miss',
#  'humpninja',
#  'cri',
#  'asian',
#  'eye',
#  'sleep',
#  'night',
#  'ok',
#  'm',
#  'sick',
#  'spent',
#  'hour',
#  'sit',
#  'shower',
#  'caus',
#  'wa',
#  'sick',
#  'stand',
#  'held',
#  'back',
#  'puke',
#  'like',
#  'champ',
#  'bed',
#  'now',
#  'cocomix',
#  'ill',
#  'tell',
#  'ya',
#  'stori',
#  'later',
#  'good',
#  'day',
#  'ill',
#  'workin',
#  'like',
#  'three',
#  'hour',
#  'missxu',
#  'sorri',
#  'bed',
#  'time',
#  'came',
#  'gmt',
#  'fleuryli',
#  'don',
#  't',
#  'either',
#  'depress',
#  'don',
#  't',
#  'think',
#  'even',
#  'want',
#  'know',
#  'kid',
#  'suitcas',
#  'bed',
#  'class',
#  'work',
#  'gym',
#  'class',
#  'anoth',
#  'day',
#  's',
#  'gon',
#  'na',
#  'fli',
#  'miss',
#  'girlfriend',
#  'realli',
#  'don',
#  't',
#  'feel',
#  'like',
#  'get',
#  'today',
#  'got',
#  'studi',
#  'tomorrow',
#  'practic',
#  'exam',
#  's',
#  'reason',
#  'teardrop',
#  'guitar',
#  'onli',
#  'one',
#  'ha',
#  'enough',
#  'break',
#  'heart',
#  'sad',
#  'sad',
#  'sad',
#  'don',
#  't',
#  'know',
#  'whi',
#  'hate',
#  'feel',
#  'wan',
#  'na',
#  'sleep',
#  'still',
#  'can',
#  't',
#  'jonathanrknight',
#  'awww',
#  'soo',
#  'wish',
#  'wa',
#  'see',
#  'final',
#  'comfort',
#  'im',
#  'sad',
#  'miss',
#  'fall',
#  'asleep',
#  'just',
#  'heard',
#  'traci',
#  'girl',
#  's',
#  'bodi',
#  'found',
#  'sad',
#  'heart',
#  'break',
#  'famili',
#  'viennah',
#  'yay',
#  'm',
#  'happi',
#  'job',
#  'also',
#  'mean',
#  'le',
#  'time',
#  'just',
#  'check',
#  'user',
#  'timelin',
#  'blackberri',
#  'look',
#  'like',
#  'twank',
#  'still',
#  'happen',
#  'ppl',
#  'still',
#  'prob',
#  'w',
#  'bgs',
#  'uid',
#  'oh',
#  'man',
#  'wa',
#  'iron',
#  'jeancjumb',
#  's',
#  'fave',
#  'top',
#  'wear',
#  'meet',
#  'burnt',
#  'strang',
#  'sad',
#  'lilo',
#  'samro',
#  'break',
#  'tea',
#  'oh',
#  'm',
#  'sorri',
#  'didn',
#  't',
#  'think',
#  'befor',
#  'retweet',
#  'broadband',
#  'plan',
#  'massiv',
#  'broken',
#  'promis',
#  'via',
#  'www',
#  'diigo',
#  'com',
#  'tautao',
#  'still',
#  'wait',
#  'broadband',
#  'localtweep',
#  'wow',
#  'ton',
#  'repli',
#  'may',
#  'unfollow',
#  'can',
#  'see',
#  'friend',
#  'tweet',
#  're',
#  'scroll',
#  'feed',
#  'lot',
#  'duck',
#  'chicken',
#  'take',
#  'wayyy',
#  'long',
#  'hatch',
#  'put',
#  'vacat',
#  'photo',
#  'onlin',
#  'yr',
#  'ago',
#  'pc',
#  'crash',
#  'now',
#  'forget',
#  'name',
#  'site',
#  'need',
#  'hug',
#  'andywana',
#  'sure',
#  'onli',
#  'po',
#  'much',
#  'want',
#  'dont',
#  'think',
#  'can',
#  'trade',
#  'away',
#  'compani',
#  'asset',
#  'sorri',
#  'andi',
#  'oanhlov',
#  'hate',
#  'happen',
#  'sad',
#  'feel',
#  'dalla',
#  'go',
#  'show',
#  'got',
#  'ta',
#  'say',
#  'though',
#  'd',
#  'think',
#  'show',
#  'use',
#  'music',
#  'game',
#  'mmm',
#  'ugh',
#  'degre',
#  'tomorrow',
#  'u',
#  'move',
#  'thought',
#  'u',
#  'alreadi',
#  'sd',
#  'hmmm',
#  'random',
#  'u',
#  'found',
#  'glad',
#  'hear',
#  'yer',
#  'well',
#  'batmanyng',
#  'miss',
#  'p',
#  's',
#  'commiss',
#  'wutcha',
#  'play',
#  'cop',
#  'blood',
#  'sand',
#  'just',
#  'leav',
#  'park',
#  'lot',
#  'work',
#  'life',
#  'cool',
#  'sad',
#  'though',
#  've',
#  'never',
#  'gotten',
#  'experi',
#  'post',
#  'coitus',
#  'cigarett',
#  'befor',
#  'now',
#  'never',
#  'will',
#  'nice',
#  'day',
#  'bad',
#  'rain',
#  'come',
#  'tomorrow',
#  'starrbbi',
#  'bad',
#  'won',
#  't',
#  'around',
#  'lost',
#  'job',
#  'can',
#  't',
#  'even',
#  'pay',
#  'phone',
#  'bill',
#  'lmao',
#  'aw',
#  'shuck',
#  'damm',
#  'back',
#  'school',
#  'tomorrow',
#  'mo',
#  'job',
#  'money',
#  'hell',
#  'min',
#  'wage',
#  'f',
#  'n',
#  'clam',
#  'hour',
#  'katortiz',
#  'forev',
#  'see',
#  'soon',
#  'lt',
#  'algonquin',
#  'agre',
#  'saw',
#  'failwhal',
#  'allllll',
#  'day',
#  'today',
#  'jdarter',
#  'oh',
#  'haha',
#  'dude',
#  'dont',
#  'realli',
#  'look',
#  'em',
#  'unless',
#  'someon',
#  'say',
#  'hey',
#  'ad',
#  'sorri',
#  'm',
#  'terribl',
#  'need',
#  'pop',
#  'ninjen',
#  'm',
#  'sure',
#  're',
#  'right',
#  'need',
#  'start',
#  'work',
#  'nikster',
#  'jare',
#  'least',
#  'realli',
#  'hate',
#  'peopl',
#  'dis',
#  'band',
#  'trace',
#  'clear',
#  'ugli',
#  'gym',
#  'attir',
#  'today',
#  'wa',
#  'puma',
#  'singlet',
#  'adida',
#  'short',
#  'black',
#  'busi',
#  'sock',
#  'leather',
#  'shoe',
#  'lucki',
#  'run',
#  'ani',
#  'cute',
#  'girl',
#  'whi',
#  'won',
#  't',
#  'show',
#  'locat',
#  'picnic',
#  'phone',
#  'smell',
#  'like',
#  'citrus',
#  'ashleyac',
#  'donkey',
#  'sensit',
#  'comment',
#  'nevertheless',
#  'd',
#  'd',
#  'glad',
#  'see',
#  'mug',
#  'asap',
#  'charger',
#  'still',
#  'awol',
#  'new',
#  'csi',
#  'tonight',
#  'fml',
#  'think',
#  'arm',
#  'sore',
#  'tenni',
#  'wonder',
#  'whi',
#  'someon',
#  'u',
#  'like',
#  'much',
#  'can',
#  'make',
#  'unhappi',
#  'split',
#  'seccond',
#  'depress',
#  'sleep',
#  'soon',
#  'just',
#  'hate',
#  'say',
#  'bye',
#  'see',
#  'tomorrow',
#  'night',
#  'statravelau',
#  'just',
#  'got',
#  'ur',
#  'newslett',
#  'fare',
#  'realli',
#  'unbeliev',
#  'shame',
#  'alreadi',
#  'book',
#  'paid',
#  'mine',
#  'missin',
#  'boo',
#  'markhardi',
#  'itm',
#  'damn',
#  'don',
#  't',
#  'ani',
#  'chalk',
#  'chalkboard',
#  'useless',
#  'blast',
#  'getti',
#  'villa',
#  'hate',
#  's',
#  'sore',
#  'throat',
#  'day',
#  's',
#  'just',
#  'get',
#  'wors',
#  'msdrama',
#  'hey',
#  'miss',
#  'ya',
#  'meet',
#  'sup',
#  'mama',
#  'tummi',
#  'hurt',
#  'wonder',
#  'hypnosi',
#  'ha',
#  'anyth',
#  's',
#  'work',
#  'get',
#  'stop',
#  'smoke',
#  'whi',
#  'alway',
#  'fat',
#  'one',
#  'januarycrimson',
#  'sorri',
#  'babe',
#  'fam',
#  'annoy',
#  'thank',
#  're',
#  'asleep',
#  'right',
#  'now',
#  'muahaha',
#  'evil',
#  'laugh',
#  'hollywoodheat',
#  'paid',
#  'attent',
#  'cover',
#  'photoshop',
#  'webpag',
#  'design',
#  'class',
#  'undergrad',
#  'wednesday',
#  'b',
#  'day',
#  'don',
#  't',
#  'know',
#  'poor',
#  'cameron',
#  'hill',
#  'pray',
#  'plea',
#  'ex',
#  'threaten',
#  'start',
#  'sh',
#  'babi',
#  'st',
#  'birthday',
#  'parti',
#  'jerk',
#  'still',
#  'headach',
#  'makeherfam',
#  'hmm',
#  'u',
#  'realli',
#  'enjoy',
#  'problem',
#  'constant',
#  'u',
#  'think',
#  'thing',
#  'find',
#  'someon',
#  'ulik',
#  'strider',
#  'sick',
#  'littl',
#  'puppi',
#  'ryle',
#  'grace',
#  'wana',
#  'go',
#  'steve',
#  's',
#  'parti',
#  'sad',
#  'sinc',
#  'easter',
#  'wnt',
#  'b',
#  'abl',
#  'much',
#  'ohh',
#  'well',
#  'hey',
#  'actual',
#  'won',
#  'one',
#  'bracket',
#  'pool',
#  'bad',
#  'wasn',
#  't',
#  'one',
#  'money',
#  'stark',
#  'don',
#  't',
#  'follow',
#  'either',
#  'work',
#  'bad',
#  'nite',
#  'favorit',
#  'team',
#  'astro',
#  'spartan',
#  'lose',
#  'nite',
#  't',
#  'w',
#  'wa',
#  'good',
#  'bodi',
#  'miss',
#  'northern',
#  'calif',
#  'girl',
#  'found',
#  'polic',
#  'found',
#  'remain',
#  'miss',
#  'northern',
#  'california',
#  'girl',
#  'mangaaa',
#  'hope',
#  'will',
#  'increas',
#  'capac',
#  'fast',
#  'yesterday',
#  'wa',
#  'pain',
#  'got',
#  'fail',
#  'whale',
#  'time',
#  'hour',
#  'behind',
#  'class',
#  'work',
#  'watch',
#  'quot',
#  'hous',
#  'quot',
#  'kprey',
#  'rememb',
#  'bum',
#  'leg',
#  'strike',
#  'back',
#  'time',
#  'serious',
#  'paradisej',
#  'cool',
#  'will',
#  'kind',
#  'complaint',
#  'laptop',
#  'onlin',
#  'overh',
#  'recal',
#  'emili',
#  'will',
#  'glad',
#  'mommi',
#  'done',
#  'train',
#  'new',
#  'job',
#  'miss',
#  'rather',
#  'first',
#  'parti',
#  'send',
#  'bad',
#  'messag',
#  'rd',
#  'parti',
#  'send',
#  'mix',
#  'one',
#  'sophmor',
#  'year',
#  'henkuyinepu',
#  's',
#  'overr',
#  'marykatherin',
#  'q',
#  'know',
#  'heard',
#  'afternoon',
#  'wonder',
#  'thing',
#  'moscow',
#  'behind',
#  'time',
#  'lay',
#  'bed',
#  'voic',
#  'm',
#  'sooo',
#  'sad',
#  'kill',
#  'kutner',
#  'hous',
#  'whyyyyyyyy',
#  'jacobsumm',
#  'sorri',
#  'tell',
#  'mea',
#  'culpa',
#  'realli',
#  'sorri',
#  'alliana',
#  'didn',
#  't',
#  'make',
#  'ani',
#  'sen',
#  'suicid',
#  'thing',
#  'refus',
#  'believ',
#  ...]

# %%
for word in lst:
    fdist[word] += 1

# %%
fdist
# Out:
# FreqDist({'s': 573687, 't': 551349, 'm': 421692, 'go': 416088, 'just': 381426, 'get': 332535, 'day': 327798, 'wa': 315099, 'can': 290043, 'now': 282186, ...})

# %%
from pandas.io.json import json_normalize
bag_of_words=json_normalize(fdist)

# %%
bag_of_words
# Out:
#     aa  aaa  aaaa  aaaaa  aaaaaa  aaaaaaa  aaaaaaaa  aaaaaaaaa  aaaaaaaaaa  \
# 0  642  360   153     90      66       24        36         21          24
#
#    aaaaaaaaaaa  ...  zzzzzzzzzzzzzzzzzzzzzz  zzzzzzzzzzzzzzzzzzzzzzz  \
# 0           12  ...                       6                        3
#
#    zzzzzzzzzzzzzzzzzzzzzzzzzz  zzzzzzzzzzzzzzzzzzzzzzzzzzz  \
# 0                           3                            9
#
#    zzzzzzzzzzzzzzzzzzzzzzzzzzzz  zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz  \
# 0                             3                                3
#
#    zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz  zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz  \
# 0                                   9                                    3
#
#    zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz  \
# 0                                                  3
#
#    zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# 0                                                  3
#
# [1 rows x 508820 columns]

# %%
bag_of_words=bag_of_words.sort_values(by=0,axis=1, ascending=False).iloc[:,0:5000]
bag_of_words=bag_of_words.T

# %%
lst_top=list(bag_of_words.index)

# %%
def find_features(document):
    words = set(document)
    features = {}
    
    for w in lst_top:
        features[w] = (w in words)
    
    return features

# %%
find_features(lst) #Obviamente mis top 5000 estan dentro de mi lst del total de palabras
# Out:
# {'s': True,
#  't': True,
#  'm': True,
#  'go': True,
#  'just': True,
#  'get': True,
#  'day': True,
#  'wa': True,
#  'can': True,
#  'now': True,
#  'good': True,
#  'work': True,
#  'like': True,
#  'love': True,
#  'quot': True,
#  'got': True,
#  'u': True,
#  'today': True,
#  'time': True,
#  'lol': True,
#  'thank': True,
#  'miss': True,
#  'one': True,
#  'back': True,
#  'want': True,
#  'know': True,
#  'will': True,
#  'see': True,
#  'feel': True,
#  'think': True,
#  'im': True,
#  'don': True,
#  'realli': True,
#  'amp': True,
#  'night': True,
#  'hope': True,
#  'watch': True,
#  'still': True,
#  'need': True,
#  'make': True,
#  'well': True,
#  'new': True,
#  'na': True,
#  'home': True,
#  'll': True,
#  'oh': True,
#  'look': True,
#  'ha': True,
#  'come': True,
#  'much': True,
#  'last': True,
#  'twitter': True,
#  'morn': True,
#  're': True,
#  'tomorrow': True,
#  'wish': True,
#  'great': True,
#  'wait': True,
#  'sad': True,
#  'sleep': True,
#  'haha': True,
#  'bad': True,
#  'fun': True,
#  'week': True,
#  'whi': True,
#  'tri': True,
#  'right': True,
#  'onli': True,
#  'follow': True,
#  'happi': True,
#  'veri': True,
#  'friend': True,
#  've': True,
#  'thing': True,
#  'sorri': True,
#  'tonight': True,
#  'say': True,
#  'way': True,
#  'take': True,
#  'gon': True,
#  'nice': True,
#  'though': True,
#  'better': True,
#  'hate': True,
#  'even': True,
#  'd': True,
#  'yeah': True,
#  'tweet': True,
#  'bed': True,
#  'start': True,
#  'school': True,
#  'hour': True,
#  'peopl': True,
#  'show': True,
#  'didn': True,
#  'yes': True,
#  'guy': True,
#  'play': True,
#  'weekend': True,
#  'hey': True,
#  'final': True,
#  'awesom': True,
#  'next': True,
#  'let': True,
#  'lt': True,
#  'use': True,
#  'dont': True,
#  'never': True,
#  'soon': True,
#  'cant': True,
#  'tire': True,
#  'long': True,
#  'rain': True,
#  'plea': True,
#  'x': True,
#  'littl': True,
#  'first': True,
#  'year': True,
#  'everyon': True,
#  'wan': True,
#  'movi': True,
#  'best': True,
#  'sick': True,
#  'life': True,
#  'girl': True,
#  'ok': True,
#  'find': True,
#  'suck': True,
#  'call': True,
#  'ani': True,
#  'sure': True,
#  'done': True,
#  'help': True,
#  'bore': True,
#  'head': True,
#  'alway': True,
#  'talk': True,
#  'keep': True,
#  'alreadi': True,
#  'cool': True,
#  'anoth': True,
#  'lot': True,
#  'live': True,
#  'someth': True,
#  'eat': True,
#  'man': True,
#  'phone': True,
#  'leav': True,
#  'read': True,
#  'hurt': True,
#  'won': True,
#  'readi': True,
#  'made': True,
#  'yay': True,
#  'enjoy': True,
#  'becaus': True,
#  'song': True,
#  'hous': True,
#  'yet': True,
#  'went': True,
#  'ur': True,
#  'n': True,
#  'befor': True,
#  'ever': True,
#  'sound': True,
#  'thought': True,
#  'pretti': True,
#  'mayb': True,
#  'amaz': True,
#  'excit': True,
#  'away': True,
#  'summer': True,
#  'game': True,
#  'omg': True,
#  'finish': True,
#  'old': True,
#  'guess': True,
#  'tell': True,
#  'damn': True,
#  'mean': True,
#  'listen': True,
#  'earli': True,
#  'o': True,
#  'someon': True,
#  'babi': True,
#  'check': True,
#  'bit': True,
#  'lost': True,
#  'give': True,
#  'left': True,
#  'b': True,
#  'big': True,
#  'end': True,
#  'wow': True,
#  'parti': True,
#  'hot': True,
#  'late': True,
#  'noth': True,
#  'hear': True,
#  'ya': True,
#  'glad': True,
#  'w': True,
#  'actual': True,
#  'birthday': True,
#  'pic': True,
#  'happen': True,
#  'hard': True,
#  'sun': True,
#  'stop': True,
#  'also': True,
#  'doesn': True,
#  'weather': True,
#  'later': True,
#  'doe': True,
#  'two': True,
#  'mom': True,
#  'wonder': True,
#  'stuff': True,
#  'th': True,
#  'ugh': True,
#  'put': True,
#  'ta': True,
#  'saw': True,
#  'run': True,
#  'exam': True,
#  'god': True,
#  'car': True,
#  'fuck': True,
#  'stay': True,
#  'might': True,
#  'music': True,
#  'world': True,
#  'p': True,
#  'yesterday': True,
#  'r': True,
#  'kid': True,
#  'said': True,
#  'meet': True,
#  'sinc': True,
#  'hi': True,
#  'job': True,
#  'beauti': True,
#  'post': True,
#  'updat': True,
#  'sunday': True,
#  'friday': True,
#  'monday': True,
#  'around': True,
#  'video': True,
#  'mani': True,
#  'com': True,
#  'seem': True,
#  'cold': True,
#  'luck': True,
#  'must': True,
#  'found': True,
#  'poor': True,
#  'cri': True,
#  'book': True,
#  'boy': True,
#  'move': True,
#  'die': True,
#  'haven': True,
#  'aww': True,
#  'busi': True,
#  'may': True,
#  'gone': True,
#  'buy': True,
#  'famili': True,
#  'anyth': True,
#  'shop': True,
#  'plan': True,
#  'studi': True,
#  'woke': True,
#  'least': True,
#  'hair': True,
#  'total': True,
#  'month': True,
#  'food': True,
#  'okay': True,
#  'cute': True,
#  'iphon': True,
#  'till': True,
#  'tho': True,
#  'lunch': True,
#  'almost': True,
#  'free': True,
#  'sweet': True,
#  'win': True,
#  'isn': True,
#  'far': True,
#  'believ': True,
#  'drink': True,
#  'chang': True,
#  'dinner': True,
#  'pictur': True,
#  'class': True,
#  'place': True,
#  'caus': True,
#  'everyth': True,
#  'funni': True,
#  'shit': True,
#  'welcom': True,
#  'c': True,
#  'gt': True,
#  'anyon': True,
#  'drive': True,
#  'forward': True,
#  'turn': True,
#  'sit': True,
#  'mine': True,
#  'without': True,
#  'walk': True,
#  'ask': True,
#  'real': True,
#  'name': True,
#  'dream': True,
#  'everi': True,
#  'write': True,
#  'stupid': True,
#  'idea': True,
#  'dad': True,
#  'clean': True,
#  'hahaha': True,
#  'outsid': True,
#  'send': True,
#  'coffe': True,
#  'ill': True,
#  'enough': True,
#  'dog': True,
#  'room': True,
#  'fan': True,
#  'wrong': True,
#  'anymor': True,
#  'wake': True,
#  'didnt': True,
#  'probabl': True,
#  'xx': True,
#  'saturday': True,
#  'tv': True,
#  'money': True,
#  'onc': True,
#  'minut': True,
#  'repli': True,
#  'rock': True,
#  'person': True,
#  'face': True,
#  'eye': True,
#  'sooo': True,
#  'el': True,
#  'break': True,
#  'serious': True,
#  'rememb': True,
#  'headach': True,
#  'aw': True,
#  'hit': True,
#  'brother': True,
#  'fail': True,
#  'blog': True,
#  'crazi': True,
#  'e': True,
#  'beach': True,
#  'train': True,
#  'came': True,
#  'whole': True,
#  'seen': True,
#  'hang': True,
#  'kill': True,
#  'open': True,
#  'kinda': True,
#  'mother': True,
#  'pain': True,
#  'rest': True,
#  'close': True,
#  'super': True,
#  'word': True,
#  'comput': True,
#  'care': True,
#  'hello': True,
#  'half': True,
#  'quit': True,
#  'text': True,
#  'took': True,
#  'hell': True,
#  'news': True,
#  'awww': True,
#  'anyway': True,
#  'pm': True,
#  'true': True,
#  'worri': True,
#  'heart': True,
#  'goodnight': True,
#  'part': True,
#  'abl': True,
#  'forgot': True,
#  'problem': True,
#  'trip': True,
#  'ago': True,
#  'offic': True,
#  'kind': True,
#  'wasn': True,
#  'bring': True,
#  'mind': True,
#  'photo': True,
#  'either': True,
#  'boo': True,
#  'full': True,
#  'g': True,
#  'link': True,
#  'danc': True,
#  'ah': True,
#  'soo': True,
#  'pay': True,
#  'hug': True,
#  'sister': True,
#  'cuz': True,
#  'couldn': True,
#  'alon': True,
#  'internet': True,
#  'y': True,
#  'hehe': True,
#  'fall': True,
#  'test': True,
#  'btw': True,
#  'stuck': True,
#  'ticket': True,
#  'sometim': True,
#  'heard': True,
#  'cours': True,
#  'email': True,
#  'pick': True,
#  'site': True,
#  'st': True,
#  'www': True,
#  'set': True,
#  'learn': True,
#  'interest': True,
#  'wont': True,
#  'pas': True,
#  'hand': True,
#  'la': True,
#  'shower': True,
#  'vote': True,
#  'nite': True,
#  'concert': True,
#  'add': True,
#  'onlin': True,
#  'ice': True,
#  'dude': True,
#  'season': True,
#  'k': True,
#  'visit': True,
#  'mileycyrus': True,
#  'cat': True,
#  'fine': True,
#  'awak': True,
#  'suppos': True,
#  'fix': True,
#  'breakfast': True,
#  'facebook': True,
#  'told': True,
#  'favorit': True,
#  'goe': True,
#  'sunni': True,
#  'smile': True,
#  'til': True,
#  'pack': True,
#  'catch': True,
#  'wear': True,
#  'ladi': True,
#  'high': True,
#  'broke': True,
#  'lmao': True,
#  'cut': True,
#  'bought': True,
#  'spend': True,
#  'june': True,
#  'lucki': True,
#  'le': True,
#  'crap': True,
#  'mad': True,
#  'red': True,
#  'asleep': True,
#  'afternoon': True,
#  'hungri': True,
#  'reason': True,
#  'ride': True,
#  'v': True,
#  'sign': True,
#  'definit': True,
#  'min': True,
#  'agre': True,
#  'laugh': True,
#  'l': True,
#  'bye': True,
#  'instead': True,
#  'tea': True,
#  'mr': True,
#  'xd': True,
#  'jealous': True,
#  'short': True,
#  'perfect': True,
#  'yea': True,
#  'citi': True,
#  'stori': True,
#  'page': True,
#  'nap': True,
#  'second': True,
#  'star': True,
#  'bout': True,
#  'wed': True,
#  'top': True,
#  'sore': True,
#  'album': True,
#  'sigh': True,
#  'homework': True,
#  'dear': True,
#  'messag': True,
#  'tommcfli': True,
#  'graduat': True,
#  'dead': True,
#  'figur': True,
#  'join': True,
#  'sing': True,
#  'tour': True,
#  'list': True,
#  'date': True,
#  'togeth': True,
#  'near': True,
#  'youtub': True,
#  'soooo': True,
#  'park': True,
#  'water': True,
#  'holiday': True,
#  'laptop': True,
#  'congrat': True,
#  'award': True,
#  'save': True,
#  'store': True,
#  'coupl': True,
#  'goin': True,
#  'point': True,
#  'moment': True,
#  'revis': True,
#  'complet': True,
#  'drop': True,
#  'relax': True,
#  'town': True,
#  'line': True,
#  'foot': True,
#  'dress': True,
#  'side': True,
#  'download': True,
#  'church': True,
#  'cook': True,
#  'order': True,
#  'account': True,
#  'annoy': True,
#  'offici': True,
#  'ipod': True,
#  'share': True,
#  'weird': True,
#  'answer': True,
#  'f': True,
#  'ppl': True,
#  'cream': True,
#  'ddlovato': True,
#  'decid': True,
#  'ive': True,
#  'lil': True,
#  'hr': True,
#  'gym': True,
#  'scare': True,
#  'lose': True,
#  'forget': True,
#  'air': True,
#  'mood': True,
#  'mum': True,
#  'realiz': True,
#  'fli': True,
#  'math': True,
#  'chat': True,
#  'unfortun': True,
#  'english': True,
#  'nd': True,
#  'understand': True,
#  'chocol': True,
#  'fb': True,
#  'co': True,
#  'past': True,
#  'pool': True,
#  'differ': True,
#  'band': True,
#  'usual': True,
#  'comment': True,
#  'ate': True,
#  'episod': True,
#  'fast': True,
#  'da': True,
#  'ahh': True,
#  'knew': True,
#  'upload': True,
#  'kick': True,
#  'window': True,
#  'london': True,
#  'black': True,
#  'support': True,
#  'worst': True,
#  'broken': True,
#  'team': True,
#  'parent': True,
#  'chanc': True,
#  'load': True,
#  'horribl': True,
#  'flight': True,
#  'hmm': True,
#  'sunshin': True,
#  'question': True,
#  'throat': True,
#  'cheer': True,
#  'yep': True,
#  'worth': True,
#  'mac': True,
#  'sat': True,
#  'xxx': True,
#  'em': True,
#  'three': True,
#  'jona': True,
#  'sleepi': True,
#  'uk': True,
#  'green': True,
#  'upset': True,
#  'special': True,
#  'card': True,
#  'via': True,
#  'fair': True,
#  'depress': True,
#  'bless': True,
#  'shirt': True,
#  'slow': True,
#  'blue': True,
#  'myspac': True,
#  'beat': True,
#  'leg': True,
#  'ad': True,
#  'number': True,
#  'sent': True,
#  'followfriday': True,
#  'gave': True,
#  'bet': True,
#  'record': True,
#  'colleg': True,
#  'moon': True,
#  'sim': True,
#  'cake': True,
#  'project': True,
#  'appar': True,
#  'david': True,
#  'paper': True,
#  'juli': True,
#  'tuesday': True,
#  'app': True,
#  'beer': True,
#  'finger': True,
#  'websit': True,
#  'power': True,
#  'vacat': True,
#  'film': True,
#  'wouldn': True,
#  'light': True,
#  'warm': True,
#  'fell': True,
#  'garden': True,
#  'wors': True,
#  'easi': True,
#  'miley': True,
#  'possibl': True,
#  'doesnt': True,
#  'aren': True,
#  'j': True,
#  'bodi': True,
#  'rather': True,
#  'shoe': True,
#  'longer': True,
#  'bday': True,
#  'freak': True,
#  'nope': True,
#  'mess': True,
#  'flu': True,
#  'wtf': True,
#  'woman': True,
#  'disappoint': True,
#  'huge': True,
#  'googl': True,
#  'mtv': True,
#  'age': True,
#  'due': True,
#  'white': True,
#  'absolut': True,
#  'celebr': True,
#  'spent': True,
#  'plus': True,
#  'safe': True,
#  'burn': True,
#  'chill': True,
#  'bike': True,
#  'lay': True,
#  'voic': True,
#  'shame': True,
#  'cancel': True,
#  'lazi': True,
#  'cousin': True,
#  'babe': True,
#  'thx': True,
#  'forev': True,
#  'bus': True,
#  'stress': True,
#  'touch': True,
#  'earlier': True,
#  'tom': True,
#  'ahhh': True,
#  'stomach': True,
#  'thursday': True,
#  'hold': True,
#  'remind': True,
#  'swim': True,
#  'quick': True,
#  'lie': True,
#  'shot': True,
#  'yr': True,
#  'cd': True,
#  'except': True,
#  'idk': True,
#  'especi': True,
#  'camp': True,
#  'camera': True,
#  'son': True,
#  'manag': True,
#  'exact': True,
#  'appl': True,
#  'box': True,
#  'slept': True,
#  'dm': True,
#  'bum': True,
#  'appreci': True,
#  'met': True,
#  'boyfriend': True,
#  'pray': True,
#  'dure': True,
#  'surpris': True,
#  'crash': True,
#  'luv': True,
#  'si': True,
#  'sort': True,
#  'shoot': True,
#  'club': True,
#  'type': True,
#  'h': True,
#  'current': True,
#  'insid': True,
#  'yummi': True,
#  'piss': True,
#  'block': True,
#  'fight': True,
#  'bitch': True,
#  'father': True,
#  'jonasbroth': True,
#  'present': True,
#  'note': True,
#  'radio': True,
#  'airport': True,
#  'cover': True,
#  'wit': True,
#  'pizza': True,
#  'servic': True,
#  'case': True,
#  'mail': True,
#  'terribl': True,
#  'havent': True,
#  'design': True,
#  'random': True,
#  'road': True,
#  'bbq': True,
#  'storm': True,
#  'confus': True,
#  'arriv': True,
#  'invit': True,
#  'chicken': True,
#  'hospit': True,
#  'meant': True,
#  'expect': True,
#  'small': True,
#  'hill': True,
#  'twilight': True,
#  'fit': True,
#  'raini': True,
#  'deal': True,
#  'cloth': True,
#  'interview': True,
#  'hubbi': True,
#  'tummi': True,
#  'doctor': True,
#  'count': True,
#  'tast': True,
#  'notic': True,
#  'proud': True,
#  'smell': True,
#  'cup': True,
#  'lone': True,
#  'laker': True,
#  'addict': True,
#  'felt': True,
#  'wine': True,
#  'mention': True,
#  'yo': True,
#  'speak': True,
#  'stand': True,
#  'shall': True,
#  'goodby': True,
#  'alright': True,
#  'begin': True,
#  'search': True,
#  'peac': True,
#  'gorgeous': True,
#  'pink': True,
#  'yup': True,
#  'fact': True,
#  'xoxo': True,
#  'ach': True,
#  'product': True,
#  'bag': True,
#  'wash': True,
#  'issu': True,
#  'ma': True,
#  'kiss': True,
#  'lame': True,
#  'tan': True,
#  'wednesday': True,
#  'practic': True,
#  'pull': True,
#  'woo': True,
#  'dvd': True,
#  'bar': True,
#  'glass': True,
#  'nick': True,
#  'connect': True,
#  'roll': True,
#  'whatev': True,
#  'hmmm': True,
#  'front': True,
#  'tear': True,
#  'compani': True,
#  'french': True,
#  'taken': True,
#  'bro': True,
#  'ouch': True,
#  'ball': True,
#  'apart': True,
#  'scari': True,
#  'joke': True,
#  'state': True,
#  'event': True,
#  'exhaust': True,
#  'drunk': True,
#  'art': True,
#  'mile': True,
#  'memori': True,
#  'mommi': True,
#  'child': True,
#  'paint': True,
#  'becom': True,
#  'normal': True,
#  'ear': True,
#  'everybodi': True,
#  'fire': True,
#  'daughter': True,
#  'jus': True,
#  'angel': True,
#  'round': True,
#  'guitar': True,
#  'isnt': True,
#  'travel': True,
#  'mate': True,
#  'behind': True,
#  'version': True,
#  'vega': True,
#  'prob': True,
#  'sold': True,
#  'rip': True,
#  'door': True,
#  'releas': True,
#  'gettin': True,
#  'plane': True,
#  'return': True,
#  'promis': True,
#  'although': True,
#  'bb': True,
#  'web': True,
#  'cross': True,
#  'puppi': True,
#  'hangov': True,
#  'matter': True,
#  'singl': True,
#  'sell': True,
#  'arm': True,
#  'magic': True,
#  'dark': True,
#  'pop': True,
#  'wife': True,
#  'allow': True,
#  'along': True,
#  'sale': True,
#  'cooki': True,
#  'fantast': True,
#  'fish': True,
#  'fri': True,
#  'alot': True,
#  'countri': True,
#  'hahah': True,
#  'bug': True,
#  'clear': True,
#  'group': True,
#  'self': True,
#  'wat': True,
#  'hotel': True,
#  'twit': True,
#  'ruin': True,
#  'death': True,
#  'track': True,
#  'eh': True,
#  'ahead': True,
#  'wast': True,
#  'act': True,
#  'screen': True,
#  'bird': True,
#  'huh': True,
#  'ohh': True,
#  'chris': True,
#  'de': True,
#  'histori': True,
#  'gosh': True,
#  'hun': True,
#  'mark': True,
#  'instal': True,
#  'ff': True,
#  'inde': True,
#  'perform': True,
#  'deserv': True,
#  'buddi': True,
#  'profil': True,
#  'aint': True,
#  'pc': True,
#  'sexi': True,
#  'daddi': True,
#  'fml': True,
#  'race': True,
#  'low': True,
#  'vip': True,
#  'cough': True,
#  'extra': True,
#  'chees': True,
#  'major': True,
#  'land': True,
#  'nobodi': True,
#  'fat': True,
#  'fill': True,
#  'gay': True,
#  'heat': True,
#  'street': True,
#  'john': True,
#  'joe': True,
#  'yum': True,
#  'taylor': True,
#  'xo': True,
#  'bloodi': True,
#  'troubl': True,
#  'posit': True,
#  'traffic': True,
#  'shine': True,
#  'kate': True,
#  'sky': True,
#  'grow': True,
#  'delet': True,
#  'tweetdeck': True,
#  'blood': True,
#  'throw': True,
#  'bill': True,
#  'nyc': True,
#  'gut': True,
#  'nose': True,
#  'vid': True,
#  'men': True,
#  'nail': True,
#  'ran': True,
#  'jon': True,
#  'prepar': True,
#  'edit': True,
#  'itun': True,
#  'step': True,
#  'recommend': True,
#  ...}

# %%
df.text_processed # a lo que entiendo, lo que piden es ver las palabras de cada tweet y compararlas con tus top 5000.

#Tendría que modificar la función creada anteriormente.
# Out:
# 0          [switchfoot, awww, s, bummer, shoulda, got, da...
# 1          [upset, can, t, updat, facebook, text, might, ...
# 2          [kenichan, dive, mani, time, ball, manag, save...
# 3                     [whole, bodi, feel, itchi, like, fire]
# 4          [nationwideclass, s, behav, m, mad, whi, becau...
# 5                                    [kwesidei, whole, crew]
# 6                                                [need, hug]
# 7          [loltrish, hey, long, time, see, yes, rain, bi...
# 8                                [tatiana, k, nope, didn, t]
# 9                                     [twittera, que, muera]
# 10                     [spring, break, plain, citi, s, snow]
# 11                                    [just, re, pierc, ear]
# 12         [caregiv, couldn, t, bear, watch, thought, ua,...
# 13         [octolinz, count, idk, whi, either, never, tal...
# 14         [smarrison, ve, first, didn, t, gun, realli, t...
# 15         [iamjazzyfizzl, wish, got, watch, miss, iamlil...
# 16         [holli, death, scene, will, hurt, sever, watch...
# 17                                               [file, tax]
# 18         [lettya, ahh, ive, alway, want, see, rent, lov...
# 19         [fakerpattypattz, oh, dear, drink, forgotten, ...
# 20            [alydesign, wa, day, didn, t, get, much, done]
# 21         [one, friend, call, ask, meet, mid, valley, to...
# 22                         [angri, barista, bake, cake, ate]
# 23                                          [week, go, hope]
# 24                                  [blagh, class, tomorrow]
# 25                                 [hate, call, wake, peopl]
# 26                     [just, go, cri, sleep, watch, marley]
# 27                               [im, sad, now, miss, lilli]
# 28         [ooooh, lol, lesli, ok, won, t, lesli, won, t,...
# 29         [meh, almost, lover, except, track, get, depre...
#                                  ...
# 1599970    [thank, eastwestch, amp, wangyip, thank, wa, j...
# 1599971    [marttn, thank, martin, imagin, interfac, ll, ...
# 1599972             [mikejonesphoto, congrat, mike, way, go]
# 1599973                  [omg, offic, space, wan, na, steal]
# 1599974    [yrclndstnlvr, ahaha, nooo, just, away, everyo...
# 1599975    [bizcoachdeb, hey, m, baack, thank, much, kind...
# 1599976             [mattycus, yeah, conscienc, clear, case]
# 1599977      [mayordoriswolf, girl, dish, quot, advic, quot]
# 1599978                                      [shebb, second]
# 1599979                                             [garden]
# 1599980    [myheartandmind, jo, jen, nemuselo, zrovna, t,...
# 1599981                       [anoth, comment, contest, yay]
# 1599982    [thrillmesoon, figur, see, tweet, facebook, st...
# 1599983    [oxhot, theri, tomorrow, drink, coffe, talk, i...
# 1599984    [heard, first, re, girl, hope, ha, look, wendi...
# 1599985    [ur, lead, singer, band, bewar, fall, prey, ls...
# 1599986                         [tarayqueen, much, ad, blog]
# 1599987              [la, r, neveer, think, will, get, well]
# 1599988    [roy, everitt, ha, good, job, s, right, got, t...
# 1599989                    [m, hip, hop, im, glad, ur, well]
# 1599990                                 [wooooo, xbox, back]
# 1599991    [rmedina, latati, mmmm, sound, absolut, perfec...
# 1599992                               [recov, long, weekend]
# 1599993                                    [scoobi, gritboy]
# 1599994    [cliff, forster, yeah, doe, work, better, just...
# 1599995               [just, woke, school, best, feel, ever]
# 1599996    [thewdb, com, veri, cool, hear, old, walt, int...
# 1599997                   [readi, mojo, makeov, ask, detail]
# 1599998    [happi, th, birthday, boo, alll, time, tupac, ...
# 1599999    [happi, charitytuesday, thenspcc, sparkschar, ...
# Name: text_processed, Length: 1600000, dtype: object

# %%
def find_features(document):
    words = set(document)
    features = {}
    
    for w in lst_top:
        features[w] = (w in words)
    
    return features
