# %% [markdown]
# # Limpieza_O3_Cuauh_perday_v3

# %%
import warnings
warnings.simplefilter("ignore")
import pandas as pd
import numpy as np
import glob, os
import datetime
import matplotlib.pyplot as plt

# %%
## Importando los datos para PM10
path = r'C:\Users\luisf\Documents\Python Projects\datamex1019\air-quality-cdmx\data_aircdmx'                     # use your path
all_files = glob.glob(os.path.join(path, "*O3.xls"))     # advisable to use os.path.join as this makes concatenation OS independent
all_files
# Out:
# ['C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2000O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2001O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2002O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2003O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2004O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2005O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2006O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2007O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2008O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2009O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2010O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2011O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2012O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2013O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2014O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2015O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2016O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2017O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2018O3.xls',
#  'C:\\Users\\luisf\\Documents\\Python Projects\\datamex1019\\air-quality-cdmx\\data_aircdmx\\2019O3.xls']

# %%
df_from_each_file = (pd.read_excel(f) for f in all_files)
df_from_each_file
concatenated_df=pd.concat([i.set_index(['FECHA']+['HORA']) for i in df_from_each_file]).reset_index()

# %%
#Filtrando por las alcaldías dentro del alcance
df=concatenated_df[["FECHA","HORA","HGM"]]

# %%
df.HORA[df.HORA==24] = 00
df.FECHA=df.FECHA.apply(str)
df.FECHA=df.FECHA.apply(lambda x: x.replace(' 00:00:00',''))
df['DATETIME']=df.FECHA + ' ' + df.HORA.apply(str)+':00:00'
#df.DATETIME=df.DATETIME.apply(lambda x: x.replace(' 00:00:00',''))
df.DATETIME=pd.to_datetime(df.DATETIME)
df.DATETIME.head()
# Out:
# 0   2000-01-01 01:00:00
# 1   2000-01-01 02:00:00
# 2   2000-01-01 03:00:00
# 3   2000-01-01 04:00:00
# 4   2000-01-01 05:00:00
# Name: DATETIME, dtype: datetime64[ns]

# %%
nulls = {}
for i in range(2003,2020):
    nulls[i]=(df.HGM[(df.FECHA >= '{}-01-01' .format(i)) & (df.FECHA <= '{}-12-31' .format(i))].isnull().sum())
nulls
# Out:
# {2003: 8760,
#  2004: 8784,
#  2005: 8760,
#  2006: 8760,
#  2007: 8760,
#  2008: 8784,
#  2009: 8760,
#  2010: 8760,
#  2011: 8760,
#  2012: 0,
#  2013: 0,
#  2014: 0,
#  2015: 0,
#  2016: 0,
#  2017: 0,
#  2018: 0,
#  2019: 0}

# %%
df_cuauh=df[["DATETIME","FECHA","HORA","HGM"]]
df_cuauh=df_cuauh[df_cuauh.FECHA >= '2012-01-01']
df_cuauh.head()
# Out:
#                   DATETIME       FECHA  HORA   HGM
# 105192 2012-01-01 01:00:00  2012-01-01     1 -99.0
# 105193 2012-01-01 02:00:00  2012-01-01     2 -99.0
# 105194 2012-01-01 03:00:00  2012-01-01     3 -99.0
# 105195 2012-01-01 04:00:00  2012-01-01     4 -99.0
# 105196 2012-01-01 05:00:00  2012-01-01     5 -99.0

# %% [markdown]
# ## -99.0 y Outliers

# %%
f, ax=plt.subplots(1)
f.set_figheight(8)
f.set_figwidth(20)
ax.scatter(df_cuauh.DATETIME, df_cuauh.HGM, color='b');

# %%
df_cuauh[df_cuauh.HGM == -99.0] = None

# %%
f, ax=plt.subplots(1)
f.set_figheight(8)
f.set_figwidth(20)
ax.scatter(df_cuauh.DATETIME, df_cuauh.HGM, color='b');

# %%
df_cuauh[df_cuauh.HGM > 160] = None

# %%
f, ax=plt.subplots(1)
f.set_figheight(8)
f.set_figwidth(20)
ax.scatter(df_cuauh.DATETIME, df_cuauh.HGM, color='b');

# %% [markdown]
# ## Max/Mean/Mode/Median...?

# %%
df_cuauh_2=df_cuauh.set_index('DATETIME')[['HGM']]

# %%
cuauh_mean=df_cuauh_2.groupby(pd.TimeGrouper('D')).mean()
cuauh_max=df_cuauh_2.groupby(pd.TimeGrouper('D')).max()
cuauh_median=df_cuauh_2.groupby(pd.TimeGrouper('D')).median()

# %%
# cuauh_mean.to_csv("../data_clean/cuauh_o3_mean_clean_v3.csv")
# cuauh_max.to_csv("../data_clean/cuauh_o3_max_clean_v3.csv")
# cuauh_median.to_csv("../data_clean/cuauh_o3_median_clean_v3.csv")
