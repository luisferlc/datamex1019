# %% [markdown]
# # IMECA's O3 Cuauh por día (v3)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from fbprophet import Prophet
import warnings
warnings.simplefilter("ignore")

plt.style.use('bmh')

# %%
def mape(y_true, y_pred):
    y_true, y_pred=np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true-y_pred)/y_true))*100

def smape(y_true,y_pred):
    return ((y_true - y_pred).abs() / (y_true.abs() + y_pred.abs())).mean() * 200

# %%
def imeca_calculation(a):
    imeca = []
    for e in a:
        e=round(e)
        if (e>0)&(e<=40):
            k= (50-0)/(40-0)
            im=k*(e-0) + 0
            imeca.append(round(im))

        elif (e>=41) & (e<=75):
            k=(100-51)/(75-41)
            im=k*(e-41) + 51
            imeca.append(round(im))

        elif (e>=76) & (e<=214):
            k=(150-101)/(214-76)
            im=k*(e-76) + 101
            imeca.append(round(im))

        elif (e>=215) & (e<=354):
            k=(200-151)/(354-215)
            im=k*(e-215) + 151
            imeca.append(round(im))

        elif (e>=355) & (e<=424):
            k=(300-201)/(424-355)
            im=k*(e-355) + 201
            imeca.append(round(im))

    return imeca

# %%
def categorizando(df):
    lst=[]
    for e in df:
        if (e>=0) & (e<50):
            lst.append('Buena')
        elif (e>=50) & (e<100):
            lst.append('Regular')
        elif (e>=100) & (e<150):
            lst.append('Mala')
        elif (e>=150) & (e<200):
            lst.append('Muy mala')
        else:
            lst.append('Ya vete de aquí woe')
    return lst

# %%
def comparando_categorias(a,b):
    lst=[]
    for e in range(len(a)):
        if a[e] == b[e]:
            lst.append(1)
        else:
            lst.append(0)
    return lst

# %% [markdown]
# ### Leyendo CSV de IMECA's directos

# %%
cuauh_imeca_real = pd.read_excel("../data_aircdmx/imeca2019.xls")

# %%
cuauh_imeca_real.Hora[cuauh_imeca_real.Hora==24] = 00
cuauh_imeca_real.Fecha=cuauh_imeca_real.Fecha.apply(str)
cuauh_imeca_real.Fecha=cuauh_imeca_real.Fecha.apply(lambda x: x.replace(' 00:00:00',''))
cuauh_imeca_real['DATETIME']=cuauh_imeca_real.Fecha + ' ' + cuauh_imeca_real.Hora.apply(str)+':00:00'
#df.DATETIME=df.DATETIME.apply(lambda x: x.replace(' 00:00:00',''))
cuauh_imeca_real.DATETIME=pd.to_datetime(cuauh_imeca_real.DATETIME)

# %%
cuauh_imeca_real.DATETIME.tail()
# Out:
# 7291   2019-10-31 20:00:00
# 7292   2019-10-31 21:00:00
# 7293   2019-10-31 22:00:00
# 7294   2019-10-31 23:00:00
# 7295   2019-10-31 00:00:00
# Name: DATETIME, dtype: datetime64[ns]

# %%
cuauh_imeca_real=cuauh_imeca_real[['DATETIME','Centro ozono']]
cuauh_imeca_real=cuauh_imeca_real.set_index('DATETIME')

cuauh_imeca_mean=cuauh_imeca_real.groupby(pd.TimeGrouper('D')).mean()
cuauh_imeca_max=cuauh_imeca_real.groupby(pd.TimeGrouper('D')).max()
cuauh_imeca_median=cuauh_imeca_real.groupby(pd.TimeGrouper('D')).median()

# %% [markdown]
# ## Ejecución del modelo

# %%
cuauh_clean_max = pd.read_csv("../data_clean/cuauh_o3_max_clean_v3.csv",index_col=[0])
cuauh_clean_median = pd.read_csv("../data_clean/cuauh_o3_median_clean_v3.csv",index_col=[0])
cuauh_clean_mean = pd.read_csv("../data_clean/cuauh_o3_mean_clean_v3.csv",index_col=[0])

# %%
split_date2='2019-01-01'
split_date1='2015-11-01'

#### Para el valor Máximo ######
train=cuauh_clean_max[(cuauh_clean_max.index>=split_date1)&(cuauh_clean_max.index<split_date2)].copy()
test=cuauh_clean_max[cuauh_clean_max.index>split_date2].copy()

#### Para la Mediana ######
train2=cuauh_clean_median[(cuauh_clean_median.index>=split_date1)&(cuauh_clean_median.index<split_date2)].copy()
test2=cuauh_clean_median[cuauh_clean_median.index>split_date2].copy()

#### Para la Mean ######
train3=cuauh_clean_mean[(cuauh_clean_mean.index>=split_date1)&(cuauh_clean_mean.index<split_date2)].copy()
test3=cuauh_clean_mean[cuauh_clean_mean.index>split_date2].copy()

# %% [markdown]
# ### Preparando para fbprophet

# %%
train=train.reset_index().rename(columns={'DATETIME':'ds','HGM':'y'})
test=test.reset_index().rename(columns={'DATETIME':'ds','HGM':'y'})

train.ds=pd.to_datetime(train.ds)
test.ds=pd.to_datetime(test.ds)
test=test.dropna()
###############################################################################
train2=train2.reset_index().rename(columns={'DATETIME':'ds','HGM':'y'})
test2=test2.reset_index().rename(columns={'DATETIME':'ds','HGM':'y'})

train2.ds=pd.to_datetime(train2.ds)
test2.ds=pd.to_datetime(test2.ds)
test2=test2.dropna()
###############################################################################
train3=train3.reset_index().rename(columns={'DATETIME':'ds','HGM':'y'})
test3=test3.reset_index().rename(columns={'DATETIME':'ds','HGM':'y'})

train3.ds=pd.to_datetime(train3.ds)
test3.ds=pd.to_datetime(test3.ds)
test3=test3.dropna()

# %% [markdown]
# ## Modelo 1

# %%
modelo=Prophet(n_changepoints=4,
               #growth='linear',
               #holidays=holidays_df,
               #changepoints=['2016-01-01','2017-02-01','2018-01-01','2018-12-31'],
               changepoint_prior_scale=0.8,
               #daily_seasonality=True,
               #yearly_seasonality=15,
               #weekly_seasonality=True,
               daily_seasonality=True,
               #yearly_seasonality=True,
               seasonality_prior_scale = 15,
               #seasonality_mode='multiplicative',
               interval_width=0.95
              ).fit(train)

# %%
pred=modelo.predict(test)

# %%
mape(test.y, pred.yhat), smape(test.y, pred.yhat)
# Out:
# (34.863737048176304, 23.56667754016928)

# %%
f, ax=plt.subplots(1)
f.set_figheight(8)
f.set_figwidth(20)
ax.scatter(test.ds, test.y, color='r',s=12)
fig=modelo.plot(pred, ax)

# %%
from fbprophet.plot import add_changepoints_to_plot
#ploteando change_pints del modelo
fig = modelo.plot(pred)
a = add_changepoints_to_plot(fig.gca(), modelo, pred)

# %%
pred
# Out:
#             ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   
# 24                          0.0  78.800018
# 25                          0.0  82.604984
# 26                          0.0  80.206870
# 27                          0.0  82.784691
# 28                          0.0  80.949630
# 29                          0.0  81.657911
# ..                          ...        ...
# 240                         0.0  62.460491
# 241                         0.0  62.202581
# 242                         0.0  63.523046
# 243                         0.0  64.260753
# 244                         0.0  67.184772
# 245                         0.0  63.943023
# 246                         0.0  65.713520
# 247                         0.0  63.105373
# 248                         0.0  63.071823
# 249                         0.0  64.563076
# 250                         0.0  65.418463
# 251                         0.0  68.408992
# 252                         0.0  65.185889
# 253                         0.0  66.931686
# 254                         0.0  64.261040
# 255                         0.0  64.133553
# 256                         0.0  65.506373
# 257                         0.0  66.226109
# 258                         0.0  69.071129
# 259                         0.0  65.699854
# 260                         0.0  67.301611
# 261                         0.0  64.497231
# 262                         0.0  64.251685
# 263                         0.0  65.526516
# 264                         0.0  66.171636
# 265                         0.0  68.967541
# 266                         0.0  65.573563
# 267                         0.0  67.178729
# 268                         0.0  64.402402
# 269                         0.0  64.207005
#
# [270 rows x 22 columns]

# %% [markdown]
# # Comparación directa de IMECA

# %% [markdown]
# ## Comparación modelo 1

# %% [markdown]
# ### Predicción

# %%
df_pred=pd.DataFrame(pred[['ds','yhat']])
df_pred=df_pred.set_index('ds')

# %%
df_pred.head(10)
# Out:
#                  yhat
# ds
# 2019-01-02  71.301908
# 2019-01-03  70.516926
# 2019-01-04  71.270048
# 2019-01-05  71.421669
# 2019-01-06  73.762435
# 2019-01-07  69.961349
# 2019-01-08  71.216479
# 2019-01-09  68.155474
# 2019-01-10  67.748157
# 2019-01-11  68.958979

# %%
df_pred.shape
# Out:
# (270, 1)

# %%
df_pred.isnull().sum() #13 NANs
df_pred=df_pred.dropna()

# %%
df_pred.shape
# Out:
# (270, 1)

# %%
df_pred['imeca_pred']=imeca_calculation(df_pred.yhat)
df_pred.head()
# Out:
#                  yhat  imeca_pred
# ds
# 2019-01-02  71.301908          94
# 2019-01-03  70.516926          94
# 2019-01-04  71.270048          94
# 2019-01-05  71.421669          94
# 2019-01-06  73.762435          99

# %% [markdown]
# ### Cuauh's IMECA real

# %%
cuauh_imeca_max.head()
# Out:
#             Centro ozono
# DATETIME
# 2019-01-01           117
# 2019-01-02            59
# 2019-01-03            73
# 2019-01-04           106
# 2019-01-05           113

# %%
df_comparison=df_pred.join(cuauh_imeca_max)[['yhat','imeca_pred','Centro ozono']]
df_comparison.head(10)
# Out:
#                  yhat  imeca_pred  Centro ozono
# ds
# 2019-01-02  71.301908          94            59
# 2019-01-03  70.516926          94            73
# 2019-01-04  71.270048          94           106
# 2019-01-05  71.421669          94           113
# 2019-01-06  73.762435          99            88
# 2019-01-07  69.961349          93            67
# 2019-01-08  71.216479          94            67
# 2019-01-09  68.155474          90            61
# 2019-01-10  67.748157          90            78
# 2019-01-11  68.958979          91           104

# %%
df_comparison['categoria_pred']=categorizando(df_comparison.imeca_pred)
df_comparison['categoria_real']=categorizando(df_comparison['Centro ozono'])
df_comparison['comparacion_imecas']=comparando_categorias(df_comparison.categoria_pred,df_comparison.categoria_real)
df_comparison.head(10)
# Out:
#                  yhat  imeca_pred  Centro ozono categoria_pred categoria_real  \
# ds
# 2019-01-02  71.301908          94            59        Regular        Regular
# 2019-01-03  70.516926          94            73        Regular        Regular
# 2019-01-04  71.270048          94           106        Regular           Mala
# 2019-01-05  71.421669          94           113        Regular           Mala
# 2019-01-06  73.762435          99            88        Regular        Regular
# 2019-01-07  69.961349          93            67        Regular        Regular
# 2019-01-08  71.216479          94            67        Regular        Regular
# 2019-01-09  68.155474          90            61        Regular        Regular
# 2019-01-10  67.748157          90            78        Regular        Regular
# 2019-01-11  68.958979          91           104        Regular           Mala
#
#             comparacion_imecas
# ds
# 2019-01-02                   1
# 2019-01-03                   1
# 2019-01-04                   0
# 2019-01-05                   0
# 2019-01-06                   1
# 2019-01-07                   1
# 2019-01-08                   1
# 2019-01-09                   1
# 2019-01-10                   1
# 2019-01-11                   0

# %%
df_comparison.comparacion_imecas.value_counts()
# Out:
# 0    141
# 1    129
# Name: comparacion_imecas, dtype: int64

# %%
129/270
# Out:
# 0.4777777777777778

# %%
df_comparison.head(100)
# Out:
#                  yhat  imeca_pred  Centro ozono categoria_pred categoria_real  \
# ds
# 2019-01-02  68.459432          90            59        Regular        Regular
# 2019-01-03  67.645691          90            73        Regular        Regular
# 2019-01-04  68.350674          90           106        Regular           Mala
# 2019-01-05  68.480511          90           113        Regular           Mala
# 2019-01-06  70.752057          94            88        Regular        Regular
# 2019-01-07  66.925005          88            67        Regular        Regular
# 2019-01-08  68.160197          90            67        Regular        Regular
# 2019-01-09  65.067811          86            61        Regular        Regular
# 2019-01-10  64.632666          86            78        Regular        Regular
# 2019-01-11  65.797026          87           104        Regular           Mala
# 2019-01-12  66.458184          87            67        Regular        Regular
# 2019-01-13  69.322682          91            49        Regular          Buena
# 2019-01-14  66.138701          87            44        Regular          Buena
# 2019-01-15  68.054680          90            92        Regular        Regular
# 2019-01-16  65.667825          87            78        Regular        Regular
# 2019-01-17  65.949753          87            49        Regular          Buena
# 2019-01-18  67.829631          90            80        Regular        Regular
# 2019-01-19  69.192090          91            78        Regular        Regular
# 2019-01-20  72.731757          97            48        Regular          Buena
# 2019-01-21  70.185926          93            65        Regular        Regular
# 2019-01-22  72.693428          97            57        Regular        Regular
# 2019-01-23  70.843345          94            76        Regular        Regular
# 2019-01-24  71.600815          96            37        Regular          Buena
# 2019-01-25  73.890277          99            45        Regular          Buena
# 2019-01-26  75.593441         101            46           Mala          Buena
# 2019-01-27  79.403815         102            49           Mala          Buena
# 2019-01-28  77.059321         101            61           Mala        Regular
# 2019-01-29  79.701061         102            94           Mala        Regular
# 2019-01-30  77.921868         102            51           Mala        Regular
# 2019-01-31  78.691922         102            40           Mala          Buena
# ...               ...         ...           ...            ...            ...
# 2019-03-13  84.743263         104           118           Mala           Mala
# 2019-03-14  83.677146         104           114           Mala           Mala
